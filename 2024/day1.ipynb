# %%
import pandas as pd

# %%
df = pd.read_csv('data/day1.csv', header=None)
first = df[0].sort_values(ascending=True).reset_index(drop=True)
second = df[1].sort_values(ascending=True).reset_index(drop=True)
sum(abs(first-second))
# Out:
# 1319616

# %%
# Out:
# 1
# 43258    20
# 47888    20
# 94333    20
# 19555    19
# 93056    19
#          ..
# 36163     1
# 35855     1
# 35633     1
# 35517     1
# 99698     1
# Name: count, Length: 525, dtype: int64

# %%
u_first = set(first.unique())
u_second = set(second.unique())

inboth = u_first.intersection(u_second)
second_value_counts = second.value_counts()

for f in first:
    if f in inboth:
        second_value_counts[f]
# Out:
# {np.int64(67584),
#  np.int64(24577),
#  np.int64(12292),
#  np.int64(12293),
#  np.int64(24582),
#  np.int64(12296),
#  np.int64(26632),
#  np.int64(40970),
#  np.int64(75786),
#  np.int64(79881),
#  np.int64(18446),
#  np.int64(14352),
#  np.int64(30738),
#  np.int64(43026),
#  np.int64(63507),
#  np.int64(88088),
#  np.int64(40985),
#  np.int64(67610),
#  np.int64(12316),
#  np.int64(55324),
#  np.int64(90146),
#  np.int64(47141),
#  np.int64(63526),
#  np.int64(32811),
#  np.int64(38955),
#  np.int64(81965),
#  np.int64(43054),
#  np.int64(45105),
#  np.int64(86068),
#  np.int64(69691),
#  np.int64(55363),
#  np.int64(65607),
#  np.int64(16457),
#  np.int64(38985),
#  np.int64(53321),
#  np.int64(51276),
#  np.int64(71756),
#  np.int64(61518),
#  np.int64(73802),
#  np.int64(18515),
#  np.int64(71767),
#  np.int64(75864),
#  np.int64(32858),
#  np.int64(71771),
#  np.int64(79962),
#  np.int64(79963),
#  np.int64(88157),
#  np.int64(26722),
#  np.int64(47203),
#  np.int64(92259),
# ...
